# %%
# Dependencies

import pandas as pd

# %%
# Set the path for CSV files

stocks_data_path = "resources\merged_industries.csv"
splits_data_path = "resources\splits_data.csv"
dividends_data_path = "resources\dividends_data.csv"

# %%
# Read the CSV file into a DataFrame

stocks_data_df = pd.read_csv(stocks_data_path)
stocks_data_df.head()
# Out:
#   ASX Code Security Group Code  \
# 0      1AD                 EQY
# 1      1AG                 EQY
# 2      3DP                 EQY
# 3      3PL                 EQY
# 4      4DS                 EQY
#
#                                     Issuer Full Name   Product Description  \
# 0  ADALTA LIMITED                                ...  ORDINARY
# 1  ALTERRA LIMITED                               ...  ORDINARY
# 2  POINTERRA LIMITED                             ...  ORDINARY
# 3  3P LEARNING LIMITED..                         ...  ORDINARY
# 4  4DS MEMORY LIMITED                            ...  ORDINARY
#
#    Last Price($) Business Date  Year                   Company Name  \
# 0          0.280      20170630  2017        Adalta Limited Ordinary
# 1          0.024      20170630  2017       Alterra Limited Ordinary
# 2          0.025      20170629  2017     Pointerra Limited Ordinary
# 3          1.045      20170630  2017  3P Learning Limited. Ordinary
# 4          0.037      20170630  2017    4DS Memory Limited Ordinary
#
#                          Sub-Industry
# 0    Biotechnology & Medical Research
# 1  Environmental Services & Equipment
# 2                            Software
# 3                            Software
# 4                   Computer Hardware

# %%
# Read the CSV file into a DataFrame

splits_data_df = pd.read_csv(splits_data_path)
splits_data_df.head()
# Out:
#   ASX Code  Splits  Year
# 0      AAU    0.20  2020
# 1      ACB    0.10  2024
# 2      ACB    0.08  2020
# 3      ACR    0.33  2021
# 4      ACR    0.25  2015

# %%
# Grouping data by ASX code and year, then summing splits

sum_splits = splits_data_df.groupby(["ASX Code","Year"])["Splits"].sum().reset_index()
sum_splits.head()
# Out:
#   ASX Code  Year  Splits
# 0      AAU  2020    0.20
# 1      ABR  2018    0.17
# 2      ABR  2020    3.50
# 3      ACB  2020    0.08
# 4      ACB  2024    0.10

# %%
# Read the CSV file into a DataFrame

dividends_data_df = pd.read_csv(dividends_data_path)
dividends_data_df.head()
# Out:
#   ASX Code  Dividends        Date
# 0      AAA       0.12  30/04/2024
# 1      AAA       0.14  27/03/2024
# 2      AAA       0.13  28/02/2024
# 3      AAA       0.12  30/01/2024
# 4      AAA       0.13  28/12/2023

# %%
# Convert Date column to datetime type

dividends_data_df["Date"] = pd.to_datetime(dividends_data_df["Date"],dayfirst=True)

# Extract Year from the Date column
# Adjust year based on whether date is before or after June 30th

dividends_data_df['Year'] = dividends_data_df['Date'].apply(lambda x: x.year - 1 if x.month < 6 else x.year)
dividends_data_df.head()
# Out:
#   ASX Code  Dividends       Date  Year
# 0      AAA       0.12 2024-04-30  2023
# 1      AAA       0.14 2024-03-27  2023
# 2      AAA       0.13 2024-02-28  2023
# 3      AAA       0.12 2024-01-30  2023
# 4      AAA       0.13 2023-12-28  2023

# %%
# Dropping the date column

dividends_data_df = dividends_data_df.drop(columns=["Date"])

# Grouping data by ASX code and year, then summing dividend amounts

sum_dividends = dividends_data_df.groupby(["ASX Code","Year"])["Dividends"].sum().reset_index()
sum_dividends.head()
# Out:
#   ASX Code  Year  Dividends
# 0      AAA  2020       0.16
# 1      AAA  2021       0.10
# 2      AAA  2022       0.76
# 3      AAA  2023       1.44
# 4      AAL  2014       0.40

# %%
# Merge splits and dividends data based on ASX code and year

merged_splits_dividends_data = pd.merge(sum_splits, sum_dividends, on=["ASX Code", "Year"], how='outer')
merged_splits_dividends_data.head(20)
# Out:
#    ASX Code  Year  Splits  Dividends
# 0       AAU  2020    0.20        NaN
# 1       ABR  2018    0.17       1.22
# 2       ABR  2020    3.50       1.60
# 3       ACB  2020    0.08        NaN
# 4       ACB  2024    0.10        NaN
# 5       ACR  2015    0.25       1.64
# 6       ACR  2021    0.33        NaN
# 7       ADS  2021    1.25       0.84
# 8       ADV  2014   20.00        NaN
# 9       AEI  2022    0.05        NaN
# 10      AFL  2018    2.00       1.06
# 11      AGE  2024    0.03        NaN
# 12      AHC  2015   10.00        NaN
# 13      AHI  2023    0.25        NaN
# 14      AIM  2016    0.08        NaN
# 15      AIM  2019    0.02        NaN
# 16      AIV  2019    0.97       1.60
# 17      AIV  2020   10.11       1.66
# 18      AJX  2020    1.04       0.70
# 19      AKA  2023    0.08        NaN

# %%
# merge merged_splits_dividends_data with stocks_data_df based on ASX code and year

complete_stock_data = pd.merge(stocks_data_df, merged_splits_dividends_data, on=["ASX Code", "Year"], how='left')
complete_stock_data.head(20)
# Out:
#    ASX Code Security Group Code  \
# 0       1AD                 EQY
# 1       1AG                 EQY
# 2       3DP                 EQY
# 3       3PL                 EQY
# 4       4DS                 EQY
# 5       88E                 EQY
# 6       8CO                 EQY
# 7       8IH                 EQY
# 8       A2M                 EQY
# 9       A3D                 EQY
# 10      AAC                 EQY
# 11      AAJ                 EQY
# 12      AAP                 EQY
# 13      AAR                 EQY
# 14      AAU                 EQY
# 15      ABA                 EQY
# 16      ABC                 EQY
# 17      ABV                 EQY
# 18      ABX                 EQY
# 19      AC8                 EQY
#
#                                      Issuer Full Name   Product Description  \
# 0   ADALTA LIMITED                                ...  ORDINARY
# 1   ALTERRA LIMITED                               ...  ORDINARY
# 2   POINTERRA LIMITED                             ...  ORDINARY
# 3   3P LEARNING LIMITED..                         ...  ORDINARY
# 4   4DS MEMORY LIMITED                            ...  ORDINARY
# 5   88 ENERGY LIMITED                             ...  ORDINARY
# 6   8COMMON LIMITED                               ...  ORDINARY
# 7   8I HOLDINGS LTD                               ...  CDI 1:1
# 8   THE A2 MILK COMPANY LIMITED                   ...  ORDINARY
# 9   AURORA LABS LIMITED                           ...  ORDINARY
# 10  AUSTRALIAN AGRICULTURAL COMPANY LIMITED.      ...  ORDINARY
# 11  ARUMA RESOURCES LIMITED                       ...  ORDINARY
# 12  AUSTRALIAN AGRICULTURAL PROJECTS LIMITED      ...  ORDINARY
# 13  ANGLO AUSTRALIAN RESOURCES NL                 ...  ORDINARY
# 14  ADCORP AUSTRALIA LIMITED                      ...  ORDINARY
# 15  AUSWIDE BANK LTD                              ...  ORDINARY
# 16  ADELAIDE BRIGHTON LIMITED                     ...  ORDINARY
# 17  ADVANCED BRAKING TECHNOLOGY LTD               ...  ORDINARY
# 18  AUSTRALIAN BAUXITE LIMITED.                   ...  ORDINARY
# 19  AUSCANN GROUP HOLDINGS LTD                    ...  ORDINARY
#
#     Last Price($) Business Date  Year  \
# 0           0.280      20170630  2017
# 1           0.024      20170630  2017
# 2           0.025      20170629  2017
# 3           1.045      20170630  2017
# 4           0.037      20170630  2017
# 5           0.057      20170630  2017
# 6           0.033      20170622  2017
# 7           0.450      20170629  2017
# 8           3.760      20170630  2017
# 9           1.070      20170630  2017
# 10          1.855      20170630  2017
# 11          0.008      20170630  2017
# 12          0.034      20170630  2017
# 13          0.044      20170630  2017
# 14          0.009      20170629  2017
# 15          5.140      20170630  2017
# 16          5.630      20170630  2017
# 17          0.006      20170630  2017
# 18          0.165      20170630  2017
# 19          0.425      20170630  2017
#
#                                          Company Name  \
# 0                             Adalta Limited Ordinary
# 1                            Alterra Limited Ordinary
# 2                          Pointerra Limited Ordinary
# 3                       3P Learning Limited. Ordinary
# 4                         4DS Memory Limited Ordinary
# 5                          88 Energy Limited Ordinary
# 6                            8COMMON Limited Ordinary
# 7                             8I Holdings Ltd CDI 1:1
# 8                The A2 Milk Company Limited Ordinary
# 9                        Aurora Labs Limited Ordinary
# 10   Australian Agricultural Company Limited Ordinary
# 11                   Aruma Resources Limited Ordinary
# 12  Australian Agricultural Projects Limited Ordinary
# 13                       Astral Resources NL Ordinary
# 14                     Antilles Gold Limited Ordinary
# 15                          Auswide Bank Ltd Ordinary
# 16                             Adbri Limited Ordinary
# 17           Advanced Braking Technology Ltd Ordinary
# 18                         ABX Group Limited Ordinary
# 19                Auscann Group Holdings Ltd Ordinary
#
#                             Sub-Industry  Splits  Dividends
# 0       Biotechnology & Medical Research     NaN        NaN
# 1     Environmental Services & Equipment     NaN        NaN
# 2                               Software     NaN        NaN
# 3                               Software     NaN        NaN
# 4                      Computer Hardware     NaN        NaN
# 5   Oil & Gas Exploration and Production     NaN        NaN
# 6                               Software     NaN        NaN
# 7                      Holding Companies     NaN        NaN
# 8                        Food Processing     NaN        NaN
# 9           Electronic Equipment & Parts     NaN        NaN
# 10                       Food Processing     NaN        NaN
# 11                                  Gold     NaN        NaN
# 12                     Fishing & Farming     NaN       0.24
# 13                                  Gold     NaN        NaN
# 14                                  Gold     NaN        NaN
# 15                                 Banks     NaN        NaN
# 16                Construction Materials     NaN       1.51
# 17        Auto, Truck & Motorcycle Parts     NaN        NaN
# 18                              Aluminum     NaN        NaN
# 19                       Pharmaceuticals     NaN        NaN

# %%
# Replace null with appropriate values for Splits and Dividends columns

complete_stock_data["Splits"].fillna(0,inplace=True)
complete_stock_data["Splits"] = complete_stock_data["Splits"] + 1
complete_stock_data["Dividends"].fillna(0,inplace=True)
complete_stock_data.head(20)
# Out:
#    ASX Code Security Group Code  \
# 0       1AD                 EQY
# 1       1AG                 EQY
# 2       3DP                 EQY
# 3       3PL                 EQY
# 4       4DS                 EQY
# 5       88E                 EQY
# 6       8CO                 EQY
# 7       8IH                 EQY
# 8       A2M                 EQY
# 9       A3D                 EQY
# 10      AAC                 EQY
# 11      AAJ                 EQY
# 12      AAP                 EQY
# 13      AAR                 EQY
# 14      AAU                 EQY
# 15      ABA                 EQY
# 16      ABC                 EQY
# 17      ABV                 EQY
# 18      ABX                 EQY
# 19      AC8                 EQY
#
#                                      Issuer Full Name   Product Description  \
# 0   ADALTA LIMITED                                ...  ORDINARY
# 1   ALTERRA LIMITED                               ...  ORDINARY
# 2   POINTERRA LIMITED                             ...  ORDINARY
# 3   3P LEARNING LIMITED..                         ...  ORDINARY
# 4   4DS MEMORY LIMITED                            ...  ORDINARY
# 5   88 ENERGY LIMITED                             ...  ORDINARY
# 6   8COMMON LIMITED                               ...  ORDINARY
# 7   8I HOLDINGS LTD                               ...  CDI 1:1
# 8   THE A2 MILK COMPANY LIMITED                   ...  ORDINARY
# 9   AURORA LABS LIMITED                           ...  ORDINARY
# 10  AUSTRALIAN AGRICULTURAL COMPANY LIMITED.      ...  ORDINARY
# 11  ARUMA RESOURCES LIMITED                       ...  ORDINARY
# 12  AUSTRALIAN AGRICULTURAL PROJECTS LIMITED      ...  ORDINARY
# 13  ANGLO AUSTRALIAN RESOURCES NL                 ...  ORDINARY
# 14  ADCORP AUSTRALIA LIMITED                      ...  ORDINARY
# 15  AUSWIDE BANK LTD                              ...  ORDINARY
# 16  ADELAIDE BRIGHTON LIMITED                     ...  ORDINARY
# 17  ADVANCED BRAKING TECHNOLOGY LTD               ...  ORDINARY
# 18  AUSTRALIAN BAUXITE LIMITED.                   ...  ORDINARY
# 19  AUSCANN GROUP HOLDINGS LTD                    ...  ORDINARY
#
#     Last Price($) Business Date  Year  \
# 0           0.280      20170630  2017
# 1           0.024      20170630  2017
# 2           0.025      20170629  2017
# 3           1.045      20170630  2017
# 4           0.037      20170630  2017
# 5           0.057      20170630  2017
# 6           0.033      20170622  2017
# 7           0.450      20170629  2017
# 8           3.760      20170630  2017
# 9           1.070      20170630  2017
# 10          1.855      20170630  2017
# 11          0.008      20170630  2017
# 12          0.034      20170630  2017
# 13          0.044      20170630  2017
# 14          0.009      20170629  2017
# 15          5.140      20170630  2017
# 16          5.630      20170630  2017
# 17          0.006      20170630  2017
# 18          0.165      20170630  2017
# 19          0.425      20170630  2017
#
#                                          Company Name  \
# 0                             Adalta Limited Ordinary
# 1                            Alterra Limited Ordinary
# 2                          Pointerra Limited Ordinary
# 3                       3P Learning Limited. Ordinary
# 4                         4DS Memory Limited Ordinary
# 5                          88 Energy Limited Ordinary
# 6                            8COMMON Limited Ordinary
# 7                             8I Holdings Ltd CDI 1:1
# 8                The A2 Milk Company Limited Ordinary
# 9                        Aurora Labs Limited Ordinary
# 10   Australian Agricultural Company Limited Ordinary
# 11                   Aruma Resources Limited Ordinary
# 12  Australian Agricultural Projects Limited Ordinary
# 13                       Astral Resources NL Ordinary
# 14                     Antilles Gold Limited Ordinary
# 15                          Auswide Bank Ltd Ordinary
# 16                             Adbri Limited Ordinary
# 17           Advanced Braking Technology Ltd Ordinary
# 18                         ABX Group Limited Ordinary
# 19                Auscann Group Holdings Ltd Ordinary
#
#                             Sub-Industry  Splits  Dividends
# 0       Biotechnology & Medical Research     1.0       0.00
# 1     Environmental Services & Equipment     1.0       0.00
# 2                               Software     1.0       0.00
# 3                               Software     1.0       0.00
# 4                      Computer Hardware     1.0       0.00
# 5   Oil & Gas Exploration and Production     1.0       0.00
# 6                               Software     1.0       0.00
# 7                      Holding Companies     1.0       0.00
# 8                        Food Processing     1.0       0.00
# 9           Electronic Equipment & Parts     1.0       0.00
# 10                       Food Processing     1.0       0.00
# 11                                  Gold     1.0       0.00
# 12                     Fishing & Farming     1.0       0.24
# 13                                  Gold     1.0       0.00
# 14                                  Gold     1.0       0.00
# 15                                 Banks     1.0       0.00
# 16                Construction Materials     1.0       1.51
# 17        Auto, Truck & Motorcycle Parts     1.0       0.00
# 18                              Aluminum     1.0       0.00
# 19                       Pharmaceuticals     1.0       0.00

# %%
#Saving the final file as a CSV

complete_stock_data.to_csv('resources\complete_stock_data.csv', index=False)
